# %% [markdown]
# <h1> Demonstration of Utilizing our GPT Interface </h1>
# <h3> Authors: Jesan Ahammed Ovi, Stone Amsbaugh. Instructor: Michael Ivanitsky </h3>

# %% [markdown]
# **Step 1:** Set up the text and vocabulary that the LLM is built off of.<br>
# You can either provide the path to your own text file, or use our default recipes dataset.

# %%
text_file = None # switch this to be a string of your own filepath
