# %% [markdown]
# <h1> Demonstration of Utilizing our GPT Interface </h1>
# <h3> Authors: Jesan Ahammed Ovi, Stone Amsbaugh. Instructor: Michael Ivanitsky </h3>

# %% [markdown]
# **Step 1:** Import all functions and classes from utility file

# %%
from master_utility import *

# %% [markdown]
# **Step 2:** Create a GPT object.

# %%
my_gpt = GPT()

# %% [markdown]
# **Step 3:** Train it for some number of iterations on a text of your choice. <br>Provide the path to the text.
# You can alternatively provide it plain text.
# **Other options:**
# * plot: True by default. Plot the loss function.
# * update: Default 50. How many iterations to be updated on the progress. Use 0 for no updates.
# * sample_prompt: Test prompt to compare model response before and after training. By default, no querying will be done.
#
# If you don't want to wait for the model to train, try setting the iterations to 100, or skip a few steps to load in the pre-trained model
# If ploting, observe the loss plot after the model is trained.
#
# There are two sample training examples below. One is for the pre-downloaded recipes text, the other will get a state of the union dataset from Kaggle and download it. Uncomment the one you want to use (or use both if you really want to)

# %%
path = Vocab.get_state_of_union_file()
my_gpt.train(n_iter = 1000, text_file=path, sample_prompt="talk about the economy, inflation, and unemployment.")

# If having issues with kaggle, or want a different dataset, uncomment this line to use the pre-downloaded dataset of recipes
# my_gpt.train(n_iter = 1000, text_file='./texts/recipes.txt', sample_prompt = "make a salad with tomatoes, olives and walnuts")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 path = Vocab.get_state_of_union_file()
# ----> 2 my_gpt.train(n_iter = 1000, text_file=path, sample_prompt="talk about the economy, inflation, and unemployment.")
#       4 # If having issues with kaggle, or want a different dataset, uncomment this line to use the pre-downloaded dataset of recipes
#       5 # my_gpt.train(n_iter = 1000, text_file='./texts/recipes.txt', sample_prompt = "make a salad with tomatoes, olives and walnuts")
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\master_utility.py:376, in GPT.train(self, n_iter, plain_text, text_file, update, plot, sample_prompt)
#     374 losses = [-1 for _ in range(n_iter)]
#     375 self.model.config.d_vocab = self.vocab.d_vocab #update vocab dimensions
# --> 376 optimizer = torch.optim.Adam(self.model.parameters(), lr=1e-3)
#     377 loss_fn = nn.CrossEntropyLoss()
#     379 sample_out_tokens = 10
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\optim\adam.py:102, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused, decoupled_weight_decay)
#      87 betas = tuple(map(_to_scalar, betas))
#      89 defaults = {
#      90     "lr": lr,
#      91     "betas": betas,
#    (...)    100     "decoupled_weight_decay": decoupled_weight_decay,
#     101 }
# --> 102 super().__init__(params, defaults)
#     104 if fused:
#     105     if differentiable:
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\optim\optimizer.py:408, in Optimizer.__init__(self, params, defaults)
#     405     param_groups = [{"params": param_groups}]
#     407 for param_group in param_groups:
# --> 408     self.add_param_group(cast(dict, param_group))
#     410 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     411 # which I don't think exists
#     412 # https://github.com/pytorch/pytorch/issues/72948
#     413 self._warned_capturable_if_run_uncaptured = True
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\_compile.py:47, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      45 disable_fn = getattr(fn, "__dynamo_disable", None)
#      46 if disable_fn is None:
# ---> 47     import torch._dynamo
#      49     # We can safely turn off functools.wraps here because the inner
#      50     # already wraps fn in the outer scope.
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\_dynamo\__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     config,
#      16     convert_frame,
#      17     eval_frame,
#      18     functional_export,
#      19     resume_execution,
#      20 )
#      21 from .backends.registry import list_backends, lookup_backend, register_backend
#      22 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\_dynamo\aot_compile.py:14
#      12 import torch
#      13 import torch.fx
# ---> 14 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      15 from torch._dynamo.graph_utils import _graph_device_type
#      16 from torch._dynamo.package import SystemInfo
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\_dynamo\convert_frame.py:60
#      58 from torch._dynamo.callback import CallbackTrigger
#      59 from torch._dynamo.distributed import get_compile_pg
# ---> 60 from torch._dynamo.symbolic_convert import TensorifyState
#      61 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      62 from torch._logging import structured
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\_dynamo\symbolic_convert.py:53
#      51 import torch
#      52 import torch._logging
# ---> 53 from torch._dynamo.exc import ObservedException, TensorifyScalarRestartAnalysis
#      54 from torch._guards import tracing, TracingContext
#      55 from torch._logging.structured import dump_file
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\_dynamo\exc.py:44
#      41 from torch._utils_internal import get_file_path_2
#      43 from . import config
# ---> 44 from .utils import counters
#      47 if TYPE_CHECKING:
#      48     import types
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\_dynamo\utils.py:69
#      67 import torch
#      68 import torch._functorch.config
# ---> 69 import torch.fx.experimental.symbolic_shapes
#      70 import torch.utils._pytree as pytree
#      71 from torch import fx
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\fx\experimental\symbolic_shapes.py:77
#      75 from torch.utils._ordered_set import OrderedSet
#      76 from torch.utils._python_dispatch import is_traceable_wrapper_subclass
# ---> 77 from torch.utils._sympy.functions import (
#      78     Application,
#      79     CeilToInt,
#      80     CleanDiv,
#      81     FloorDiv,
#      82     FloorToInt,
#      83     IntTrueDiv,
#      84     IsNonOverlappingAndDenseIndicator,
#      85     Max,
#      86     Mod,
#      87     PythonMod,
#      88     TruncToInt,
#      89 )
#      90 from torch.utils._sympy.numbers import int_oo
#      91 from torch.utils._sympy.printers import CppPrinter, PythonPrinter
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\utils\_sympy\functions.py:614
#     610             raise ValueError("negative shift count")
#     611         return FloorDiv(base, 2**shift)
# --> 614 class MinMaxBase(Expr, LatticeOp):  # type: ignore[misc]
#     615     def __new__(cls, *original_args, **assumptions):
#     616         from sympy.core.parameters import global_parameters
#
# File c:\Users\amsba\Desktop\Coding\Class\LLMs\a1_transformer\.venv\Lib\site-packages\torch\utils\_sympy\functions.py:663, in MinMaxBase()
#     657     obj.unique_summations_symbols = unique_summations_symbols
#     658     return obj
#     660 @classmethod
#     661 def _satisfy_unique_summations_symbols(
#     662     cls, args
# --> 663 ) -> set[sympy.core.symbol.Symbol] | None:
#     664     """
#     665     One common case in some models is building expressions of the form
#     666     max(max(max(a+b...), c+d), e+f) which is simplified to max(a+b, c+d, e+f, ...).
#    (...)    688     property. Otherwise, it returns a new set of unique symbols.
#     689     """
#     690     if len(args) != 2:
#
# AttributeError: module 'sympy' has no attribute 'core'

# %% [markdown]
# **Step 4:** Before doing anything else, save the model.
# It saves the model parameters as well as the vocabulary the model is associated with.
# Just enter the name of the model, not the file path

# %%
my_gpt.save('state_of_union_model')

# %% [markdown]
# **Step 5:** If starting fresh, you can load the model like so

# %%
my_gpt = GPT.load_gpt_from('state_of_union_model')

# %% [markdown]
# **Step 6:** Now, query the model!

# %%
my_gpt.query("Tell me about the economy, specifically unemployment, inflation, tariffs and taxes.")
# Out:
# 'the process spirit to the bill this among and already job can the rare minority '

# %% [markdown]
# **Step 7 (bonus)** Enter a chat with the model!
# In this Jupyter notebook, there is a special widget to make it look like a CLI. Run it via command line or in a python file for a true CLI.

# %%
my_gpt.chat()
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
# Text(value='', continuous_update=False, description='>>>', layout=Layout(width='100%'), placeholder='type mess…
